# %%
# !pip install pgmpy
# Out:
# Requirement already satisfied: pgmpy in c:\users\cbit\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: huggingface_hub>=0.23 in c:\users\cbit\anaconda3\lib\site-packages (from pgmpy) (1.8.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\cbit\anaconda3\lib\site-packages (from pgmpy) (3.4.2)
# Requirement already satisfied: numpy>=2.0 in c:\users\cbit\anaconda3\lib\site-packages (from pgmpy) (2.1.3)
# Requirement already satisfied: scipy>=1.10 in c:\users\cbit\anaconda3\lib\site-packages (from pgmpy) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.2 in c:\users\cbit\anaconda3\lib\site-packages (from pgmpy) (1.6.1)
# Requirement already satisfied: pandas>=1.5 in c:\users\cbit\anaconda3\lib\site-packages (from pgmpy) (2.2.3)
# Requirement already satisfied: statsmodels>=0.14.5 in c:\users\cbit\anaconda3\lib\site-packages (from pgmpy) (0.14.6)
# Requirement already satisfied: tqdm>=4.64 in c:\users\cbit\anaconda3\lib\site-packages (from pgmpy) (4.67.1)
# Requirement already satisfied: pyparsing>=3.0 in c:\users\cbit\anaconda3\lib\site-packages (from pgmpy) (3.2.0)
# Requirement already satisfied: joblib>=1.2 in c:\users\cbit\anaconda3\lib\site-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: opt_einsum>=3.3 in c:\users\cbit\anaconda3\lib\site-packages (from pgmpy) (3.4.0)
# Requirement already satisfied: scikit-base>=0.12.4 in c:\users\cbit\anaconda3\lib\site-packages (from pgmpy) (0.13.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\cbit\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\cbit\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\cbit\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\cbit\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\cbit\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\cbit\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (6.0.2)
# Requirement already satisfied: typer in c:\users\cbit\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\cbit\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (4.12.2)
# Requirement already satisfied: anyio in c:\users\cbit\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (4.7.0)
# Requirement already satisfied: certifi in c:\users\cbit\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\cbit\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (1.0.9)
# Requirement already satisfied: idna in c:\users\cbit\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\cbit\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cbit\anaconda3\lib\site-packages (from pandas>=1.5->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cbit\anaconda3\lib\site-packages (from pandas>=1.5->pgmpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cbit\anaconda3\lib\site-packages (from pandas>=1.5->pgmpy) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\cbit\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5->pgmpy) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\cbit\anaconda3\lib\site-packages (from scikit-learn>=1.2->pgmpy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\cbit\anaconda3\lib\site-packages (from statsmodels>=0.14.5->pgmpy) (1.0.1)
# Requirement already satisfied: colorama in c:\users\cbit\anaconda3\lib\site-packages (from tqdm>=4.64->pgmpy) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\cbit\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (1.3.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\cbit\anaconda3\lib\site-packages (from typer->huggingface_hub>=0.23->pgmpy) (8.1.8)

# %%
from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.estimators import ParameterEstimator
from pgmpy.inference import VariableElimination
import pandas as pd

# %%
data = pd.DataFrame({
    'Rain': [
        'Yes','Yes','Yes','Yes','No','No','No','No',
        'Yes','Yes','No','No'
    ],
    'TrafficJam': [
        'Yes','Yes','No','Yes','No','No','Yes','No',
        'Yes','No','Yes','No'
    ],
    'ArriveLate': [
        'Yes','Yes','No','Yes','No','No','Yes','No',
        'Yes','No','Yes','No'
    ]
})

# %%
model = DiscreteBayesianNetwork([('Rain', 'TrafficJam'), ('TrafficJam', 'ArriveLate')])
model.fit(data)
print(model.get_cpds())
# Out:
# [<TabularCPD representing P(Rain:2) at 0x24f40c647a0>, <TabularCPD representing P(TrafficJam:2 | Rain:2) at 0x24f40c64830>, <TabularCPD representing P(ArriveLate:2 | TrafficJam:2) at 0x24f40c648c0>]

# %%
inference = VariableElimination(model)
query_result = inference.query(variables=['ArriveLate'], evidence={'Rain': 'Yes'})
print(query_result)
# Out:
# +-----------------+-------------------+
# | ArriveLate      |   phi(ArriveLate) |
# +=================+===================+
# | ArriveLate(No)  |            0.3333 |
# +-----------------+-------------------+
# | ArriveLate(Yes) |            0.6667 |
# +-----------------+-------------------+
